# %% [markdown]
# # Unsupervised learning
# unsupervide learning is similar to supervised learning but it does not have the target column. It learns from datasets and tries to find patterns. One can find insights without knowing much about the dataset.
# # Applications
# 1. Clustering
# 2. Anomaly detection
# 3. Association
#
# ## Clustering
# clustering identifies groups in dataset, the observation in the groups share strong similarity with member than with member of other groups.
# ### Example

# %%
from IPython.display import Image
Image(filename='Desktop/Capture01.PNG')

# %% [markdown]
# A dataset with 6 observations, what clusters could the algiorithm detect?? It depents! Here are some Posiblities.
# ## Cluster by Species
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cluster by Color
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cluster by Origin
# ![image.png](attachment:image.png)

# %% [markdown]
# # CLustering Models
# 1. K Means
# it requires to spacifies the number of cluster.
# 2. DBSCAN (destiny_based spatial clustering of applications with noise)
# It does not require you to spacify the number of cluster, Number of cluster is automatic in DBNSCAN.
#
# # Iris table
# Flowr of unknow species, all data we have is (petal length, and petal width), we dont have a column with the label species. We dont know which species we are dealing with and how many species are here.
# ![image.png](attachment:image.png)

# %% [markdown]
# If we hypothesis there are 4 species we can use a K-means
# # K-Means with 4 clusters
# ![image.png](attachment:image.png)

# %% [markdown]
# # K-Means with 3 clusters
# ![image.png](attachment:image.png)
# These clusters are actuly correct as there are 3 different species in the dataset.
# 1. sitosa
# 2. Veginika
# 3. Versicolar

# %% [markdown]
# # Anomaly Detection
# Its all about detecting outliers.<br>
# Outliers are observations that are strongly different from others.
# ![image.png](attachment:image.png)
# In the image all of points are grouped in bottom-left except one, that is in top-rigt. This point is an outlier. This point is the sum total of the other observations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Asociation
# Finding events that happen gether.
# ## Ex:
# 1. people who buy books are likely to buy bag
# 2. people who buy jam are likly to buy bread.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# # Evaluating performance
# ## Overfitting
# When the built Model performs great on training data and performs poorly on testing data.<br>
# This means model has memorized training and cant predtict new data which is we actuly want.
# <br>
# This is why we need to split the dataset into 2 parts so that we can check model's performance by remaining data which the model does not know, which is new to model.
# ![image.png](attachment:image.png)
# The green line shown in image overfits, its going out of its way to classify perfectly on the training dataset and poorly on testing dataset. <br>
# The black line makes more error on the spacific dataset.

# %% [markdown]
# # How to measure the model's performance?
# ## We could use accuracy
# Accuracy = correctly classified observation/ all observations
# <br>
# If we had 48 correct classifications out of 50.
# <br> 48/50 = 96% Acuurate.

# %% [markdown]
# ![image.png](attachment:image.png)
# This model is missing majority of fraudent transactions even if its 93.33% accurate.
# #### In this case we need a better matrix

# %% [markdown]
# # Confusion metrix
# ![image.png](attachment:image.png)
# 1. true positive = 1 data point is correctly predicted fraudent.
# 2. False negetive(like telling a pragnent women she isnt) = 2 data points are incorectly predectid fraudent and are said legitimate.
# 3. False positive(like telling a man he is pregnant) = None of legitimate is not predicted incorrectly.
# 4. true negative = 27 data points are correctly predicted legitimate.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ****
