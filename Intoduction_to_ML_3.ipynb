# %% [markdown]
# # Improving performance
# How to Improve model if unsatisfied with its performance?
# 1. Dimentionality reduction
# 2. Hyperparameter tuning
# 3. Ensemble method

# %% [markdown]
# # 1. Dimentionality reduction
# dimention denotes the number of features in the data.It means reducing the number of features.
# 1. irrelevance : unnecesary data
# 2. correlation : some features could be heighly co-related, even if we keep one of those we still can drive other features. i.e:  height and shoes size = tall people have large shoe size.

# %% [markdown]
# # 2. Hyperparameter tuning
# Hyperparameter is a value, and it totally depends on dataset that what value fits in.
# ![image.png](attachment:image.png)
#
# In SVM different hyperparametrs are given, model was poor when it was linear, it worked better when hyperparameter was changed to poly.

# %% [markdown]
# # 3. Ensemble method
#
# in Ensemble method different models are combined for predection, below case says modelA and modelC has accepted but modelB has rejected, so we will go with most common prediction
# ![image.png](attachment:image.png)

# %% [markdown]
# Below example says if we are working with regression and all of the model give diffferent predictions so avarege will be taken.
# ![image.png](attachment:image.png)
