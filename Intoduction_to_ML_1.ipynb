# %% [markdown]
# # ARTIFICIAL INTELLIGENCE

# %%
#import image library
from IPython.display import Image

# %%
#read image 
Image(filename='Desktop/Capture.PNG')

# %% [markdown]
# AI AND ML algorithms are beating humans in many ways. i.e; Chess game, better medical dignoses, better treatments, intelligent assistance.
# # AI
# a huge set of tools that make machine/computers behave intelligently.
# # ML
# Machine learning is powerfull subset of Artificial Intelligence. Defining ML is not simple, it has number of applications that overlap with several other fields. Because of the rapid growth in the field the boundries of the field are blury.
# ### Defination of ML
# here I'll define ML as set of tools for making infrances (conclusions) and predictions from raw data.
# ##### Prediction
# Predict future events <br>
# i.e:Will it rain tommorow? <br>
# Yes (78%) Probablity. <br>
# #### Infer
# The causes of events and behaviors<br>
# Drawing insights<br>
# i.e: Why does it rain?? <br>
# because of time of year, temprature, location <br>
# ## How does ML work?
# Ml is called interdisciplinary which means mixture of statistics and computer science. Ml has abality to learn without being explicitly programmed. Computer can learn without step by step instructions. ML firstly learns patterns from existing data and applies that learning on new data.
# example: spam mails learnt from archive mails and further classifies spam mails. ML needs high quality data to be succesful.
# ## Data Science
# Data science is about maikg discoveries and creating meaningfull insights from data. ML is often an important tool for Data Science for making predictions from data and creating insights.

# %% [markdown]
# # ML model

# %%
Image(filename='Desktop/Capture1.PNG')

# %% [markdown]
# ML model is Statistical representation of real world process based on data. i.e: how we recognize cats by model, predict hourly changes in traffic. We can inter new inputs in to model to get an output.
# #### Example:
# we can add a future date and hour to check traffic situation/condition in future. <br>
# The output can be a probablity too, i.e: The probablity(%) of the is fake.

# %% [markdown]
# ***

# %% [markdown]
# # Machine Learning Concepts
# ## Types:
# There are three types of Machine learning<br>
# 1> Rainforcment<br>
# 2> Supervised learning<br>
# 3> Unsupervised learning<br>
# ## Rainforcement
# Rainforcement learning is used for deciding sequential actions. Like a robot deciding its path, moves in chess game. Rainforement is not as common like others, It uses complex maths like game theory. <br>
# <br>
# The most common types are supervised and unsupervised learning, their main difference lies in the training data. <br>
# #### NOTE:
# ML uses existing data to learn paterns and applies it to new data. The existing data is Training data.
#
# # Training Data
# Training data is existing data to learn from.
# # Training a Model
# When a model is being built from training data the process is known as training the model.Training a model can take seconds to weeks as it depends on the size of data.

# %% [markdown]
# # Training Data for supervised learning model
# Suppose a model is being built that detects and says weather a person has heart disease or not. We have collected dataset of patients who had experienced it and been tested for heart disease. Targer variable is heart disease. This is what we actully want to predict.The values True and false are labels for target variable.
# ### Note:
# labels can be numbers and catogeries too.

# %%
Image(filename='Desktop/Capture2.PNG')

# %% [markdown]
# # Columns
# Columns are features. Features are different peices of information that help to predict the target.

# %% [markdown]
# ## Data in each column (Age, Sex, Cholestrol etc..)
# The values in each column/Rows data are observation and exampls that our model will learn from.

# %% [markdown]
# # Aftere Training
# Once training is done, model is built, we can give new data to model for predictions, in our case a new patient's data to see if they have heart disease. The features are inputed and model outputs its prediction.

# %%
Image(filename='Desktop/Capture3.PNG')

# %% [markdown]
# # SUPERVISED LEARNING
# The training data for supervised learning is labeled. In our dataset we already knew the petients' have heart disease, based on labels (True and False)

# %% [markdown]
# # UNSUPERVISED LEARNING
# In unsupervised learning we dont have labels only features
# ## What can we do with the features???
# We can do Anomly Detection <br>
# Clustering = Divide data into groups based on similarity.
# # UNSUPERVISED LEARNING Training Data
# There are different treatments for heart disease for different types of patients.
# #### USE OF UNSUPERVISED LEARNING
# We can use unsupervised learning to understand the different types of patients we have.

# %%
Image(filename='Desktop/Capture4.PNG')

# %% [markdown]
# We can divide the data into three(3) clusters based on features simalarity
# ### Example:
# ##### Type1 :
# Patient with high cholestrol
# ##### Type2 :
# Smoker
# ##### Type3 :
# Chest pain
# <br>
# WE CAN NOW ADD A NEW PATIENT'S DATA TO SEE WHAT TYPE IT BELONGS TO.

# %%
Image(filename='Desktop/Capture5.PNG')

# %% [markdown]
# ***

# %% [markdown]
# # Machine Learning Workflow
# Training data is used to let a model learn. The can further be used for predictions.
# What are the Steps in between, from training model to predictions by model.
# ## Steps
# There are four steps that go into buildinga a model. Working on a dataset to build a model and see all steps.
# ## Dataset.
# This dataset is a record of every building or building unit (apartment, etc.) sold in the New York City property market over a 12-month period.
# <br>
# This dataset contains the location, address, type, sale price, and sale date of building units sold etc....
# ## Target
# Sale Price<br>
# ### NOTE:
# scince we have our target (column) in dataset, this is supervised learning.
#
# # Step 1: Extract Features
# There is work to be done is reformating dataset, as its not always clean.
# # Step 2: Split dataset
# Once the data is cleaned/reformated it is to be divided into 2 parts,<br>
# 1> Train dataset<br>
# 2> Test dataset
# # Step 3: Training Model
# The dataset is inputed into choseen ML model, There are various ML models, i.e: CNN/Logistic Regression
# # Step 4: Evaluate
# For evalution of model we use the test data(unsen data), to see if model predicts correctly. If not, tune the model and retrain it.

# %%
Image(filename='Desktop/Capture6.PNG')

# %% [markdown]
# ***

# %% [markdown]
# # SUPERVISED LEARNING
# ML is all about modeling. Supervised learning is a labeling machine. It takes an observation and assigns a label to it. There are two flavours of supervised learning.
# 1. Claasification
# 2. Regression
# ## Classification
# assigning a cetegory.
# ##### EX:
# What day is today? <br>
# monday, tuesday, friday <br>
# Is it cold outside? <br>
# Yes/Nope
# ## Observations
# we feed the model observations.

# %%
Image(filename='Desktop/Capture7.PNG')

# %% [markdown]
# Here students' test data set is provided, The features (GPA nd Test results) are observed and the target is shown (Accepted)
# # Graphing data
# Data can also be graphed.
# # Spliting
# 70 to 80% data is given for training.
# # Classifier
# We can use a Support Vactor Machine to classify our data.

# %%
Image(filename='Desktop/Capture8.PNG')

# %% [markdown]
# The l classifier shows that two blue points are considered as red, this means our model has wrongly predicted two applicants as rejected.

# %%
Image(filename='Desktop/Capture9.PNG')

# %% [markdown]
# we can recover model's behavior by allowing curves in it, so that it predicts better.

# %% [markdown]
# ***

# %% [markdown]
# # Regression
# regression assigns a countinuous variable.
# ### Ex:
# how tall this child be as an adult? <br>
# ## Predicting Temprature
# Can we predict temprature on the bases of humidity ?

# %%
Image(filename='Desktop/Capture10.PNG')

# %%
Image(filename='Desktop/Capture11.PNG')

# %% [markdown]
# 80% of data is used for training the model. Seems like when humidity(x-axis) rises temprature(y_axis) increases.

# %%
Image(filename='Desktop/Capture12.PNG')

# %%
Image(filename='Desktop/Capture13.PNG')

# %% [markdown]
# On the bases of Humidity we found that the heigher humidity is the heigher temprature gets.

# %% [markdown]
# *****
